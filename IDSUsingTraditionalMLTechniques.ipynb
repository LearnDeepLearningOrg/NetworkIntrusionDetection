# %% [markdown]
# ## Import the required libraries and the utility modules

# %%
#Custom libraries
#Data formating library
from datainspectionlibrary import getStatisticsOfData
from dataformatinglibrary import createExcelFromArray

from dataloadinglibrary import loadCSV

from defineInputs import getLabelName
from defineInputs import getPathToTrainingAndTestingDataSets
from defineInputs import modelPerformanceReport
from defineInputs import defineArrayOfModels
from defineInputs import modelPerformanceReport

from util import compareModels
from util import performPreprocessingBuildModelsAndEvaluateAccuracy

# %%
#First step: Feature selection
print('**************************************************************************************************************************')
print('**************************************************** First step: Feature selection ***************************************')
print('\nFeature selection is also known as attribute selection is a process of extracting the most relevant features from the dataset  and then applying machine learning algorithms for the better performance of the model. A large number of irrelevant features increases the training time exponentially and increase the risk of overfitting.')
print('\nBroadly there are three groups of feature selection techniques \n\t1. Univariate Selection \n\t2. Feature Importance \n\t3. Correlation Matrix with Heatmap \n\t4. Embedded methods')
print('\n************************************************************************************************************************')

#Second step: Feature encoding
print('**************************************** Second step: Encode the categorical features **********************************')
print('\nMost of the Machine learning algorithms can not handle categorical variables unless they are converted to numerical values and many algorithm’s performance varies based on how Categorical variables are encoded.')
print('\nHere are most commonly used feature encoding techniques \n\t1. One-hot encoding \n\t2. Label Encoding \n\t3. Binary encoding \n\t4. Mean encoding \n\t5. Frequency encoding')
print('\n************************************************************************************************************************')

#Third step: Apply feature scaling after feature encoding
print('*************************************************** Third step: Feature Sacline ****************************************')
print('\nFeature Scaling is a technique to standardize the independent features present in the data in a fixed range. Feature scaling should be done, so that no feature (with large values) will dominate the other features.')
print('\nHere are most commonly used feature scaling techniques \n\t1. Min-Max Scaling \n\t2. Standardization \n\t3. Binarizing \n\t4. Normalizing')
print('\n************************************************************************************************************************')

#Fourth step: Apply clasification
print('********************************************* Fourth step: Apply Classification ****************************************')
print('\nHere are classification techniques that are used \n\t1. DecisonTree \n\t2. RandomForestClassifier \n\t3. ExtraTreesClassifier \n\t4. LogisticRegressionRegression \n\t5. LinearDiscriminantAnalysis \n\t6. GuassianNaiveBayes \n\t7. KNeighborsClassifier \n\t8. SVM \n\t9. DNN')
print('\n************************************************************************************************************************')
# Out:
# **************************************************************************************************************************
# **************************************************** First step: Feature selection ***************************************
#
# Feature selection is also known as attribute selection is a process of extracting the most relevant features from the dataset  and then applying machine learning algorithms for the better performance of the model. A large number of irrelevant features increases the training time exponentially and increase the risk of overfitting.
#
# Broadly there are three groups of feature selection techniques
# 	1. Univariate Selection
# 	2. Feature Importance
# 	3. Correlation Matrix with Heatmap
# 	4. Embedded methods
#
# ************************************************************************************************************************
# **************************************** Second step: Encode the categorical features **********************************
#
# Most of the Machine learning algorithms can not handle categorical variables unless they are converted to numerical values and many algorithm’s performance varies based on how Categorical variables are encoded.
#
# Here are most commonly used feature encoding techniques
# 	1. One-hot encoding
# 	2. Label Encoding
# 	3. Binary encoding
# 	4. Mean encoding
# 	5. Frequency encoding
#
# ************************************************************************************************************************
# *************************************************** Third step: Feature Sacline ****************************************
#
# Feature Scaling is a technique to standardize the independent features present in the data in a fixed range. Feature scaling should be done, so that no feature (with large values) will dominate the other features.
#
# Here are most commonly used feature scaling techniques
# 	1. Min-Max Scaling
# 	2. Standardization
# 	3. Binarizing
# 	4. Normalizing
#
# ************************************************************************************************************************
# ********************************************* Fourth step: Apply Classification ****************************************
#
# Here are classification techniques that are used
# 	1. DecisonTree
# 	2. RandomForestClassifier
# 	3. ExtraTreesClassifier
# 	4. LogisticRegressionRegression
# 	5. LinearDiscriminantAnalysis
# 	6. GuassianNaiveBayes
# 	7. KNeighborsClassifier
# 	8. SVM
# 	9. DNN
#
# ************************************************************************************************************************

# %% [markdown]
# ### Load the training dataset and check the statistics

# %%
#Define file names and call loadCSV to load the CSV files
trainingFileNameWithAbsolutePath, testingFileNameWithAbsolutePath = getPathToTrainingAndTestingDataSets()
trainingDataSet = loadCSV(trainingFileNameWithAbsolutePath)
difficultyLevel = trainingDataSet.pop('difficulty_level')
labelName = getLabelName()
label = trainingDataSet[labelName]

#Look at the statistics of the dataSet
getStatisticsOfData(trainingDataSet)
print("\n***** Here is how to training dataset looks like before performing any pre-processing *****")
trainingDataSet.head()
# Out:
# ***** Start checking the statistics of the dataSet *****
#
# ***** Shape (number of rows and columns) in the dataset:  (25191, 42)
# ***** Total number of features in the dataset:  41
# ***** Number of categorical features in the dataset:  3
# ***** Number of numerical features in the dataset:  38
#
# ***** Names of categorical features in dataset *****
#
# | Categorical features in dataset   |
# |-----------------------------------|
# | Protocol_type                     |
# | Flag                              |
# | Service                           |
#
#
# ***** Names of numerical features in dataset *****
#
# | Numerical features in the dataset   |
# |-------------------------------------|
# | Duration                            |
# | Src_bytes                           |
# | Dst_bytes                           |
# | Land                                |
# | Wrong_fragment                      |
# | Urgent                              |
# | Hot                                 |
# | Num_failed_logins                   |
# | Logged_in                           |
# | Num_compromised                     |
# | Root_shell                          |
# | Su_attempted                        |
# | Num_root                            |
# | Num_file_creations                  |
# | Num_shells                          |
# | Num_access_files                    |
# | Num_outbound_cmds                   |
# | Is_hot_login                        |
# | Is_guest_login                      |
# | Count                               |
# | Srv_count                           |
# | Serror_rate                         |
# | Srv_serror_rate                     |
# | Rerror_rate                         |
# | Srv_rerror_rate                     |
# | Same_srv_rate                       |
# | Diff_srv_rate                       |
# | Srv_diff_host_rate                  |
# | Dst_host_count                      |
# | Dst_host_srv_count                  |
# | Dst_host_same_srv_rate              |
# | Dst_host_diff_srv_rate              |
# | Dst_host_same_src_port_rate         |
# | Dst_host_srv_diff_host_rate         |
# | Dst_host_serror_rate                |
# | Dst_host_srv_serror_rate            |
# | Dst_host_rerror_rate                |
# | Dst_host_srv_rerror_rate            |
#
#
# ***** Are there any missing values in the data set:  False
# Total number of records in the dataset: 25191
# Unique records in the dataset: 25191
#
# ***** Are there any duplicate records in the data set:  False
#
# ****** Number of different values for label that are present in the dataset:  22
#
# ****** Here is the list of unique label types present in the dataset *****
#
# | Unique label types in the dataset   |
# |-------------------------------------|
# | normal                              |
# | neptune                             |
# | warezclient                         |
# | ipsweep                             |
# | portsweep                           |
# | teardrop                            |
# | nmap                                |
# | satan                               |
# | smurf                               |
# | pod                                 |
# | back                                |
# | guess_passwd                        |
# | ftp_write                           |
# | multihop                            |
# | rootkit                             |
# | buffer_overflow                     |
# | imap                                |
# | warezmaster                         |
# | phf                                 |
# | land                                |
# | loadmodule                          |
# | spy                                 |
#
#
# ****** Here is the list of unique values present in each categorical feature in the dataset *****
#
#
# Service: 66
# | distinct values   |
# |-------------------|
# | other             |
# | private           |
# | http              |
# | remote_job        |
# | ftp_data          |
# | name              |
# | netbios_ns        |
# | eco_i             |
# | mtp               |
# | telnet            |
# | finger            |
# | domain_u          |
# | supdup            |
# | uucp_path         |
# | Z39_50            |
# | smtp              |
# | csnet_ns          |
# | uucp              |
# | netbios_dgm       |
# | urp_i             |
# | auth              |
# | domain            |
# | ftp               |
# | bgp               |
# | ldap              |
# | ecr_i             |
# | gopher            |
# | vmnet             |
# | systat            |
# | http_443          |
# | efs               |
# | whois             |
# | imap4             |
# | iso_tsap          |
# | echo              |
# | klogin            |
# | link              |
# | sunrpc            |
# | login             |
# | kshell            |
# | sql_net           |
# | time              |
# | hostnames         |
# | exec              |
# | ntp_u             |
# | discard           |
# | nntp              |
# | courier           |
# | ctf               |
# | ssh               |
# | daytime           |
# | shell             |
# | netstat           |
# | pop_3             |
# | nnsp              |
# | IRC               |
# | pop_2             |
# | printer           |
# | tim_i             |
# | pm_dump           |
# | red_i             |
# | netbios_ssn       |
# | rje               |
# | X11               |
# | urh_i             |
# | http_8001         |
#
#
# Protocol_type: 3
# | distinct values   |
# |-------------------|
# | udp               |
# | tcp               |
# | icmp              |
#
#
# Flag: 11
# | distinct values   |
# |-------------------|
# | SF                |
# | S0                |
# | REJ               |
# | RSTR              |
# | SH                |
# | RSTO              |
# | S1                |
# | RSTOS0            |
# | S3                |
# | S2                |
# | OTH               |
#
#
# attack_type: 22
# | distinct values   |
# |-------------------|
# | normal            |
# | neptune           |
# | warezclient       |
# | ipsweep           |
# | portsweep         |
# | teardrop          |
# | nmap              |
# | satan             |
# | smurf             |
# | pod               |
# | back              |
# | guess_passwd      |
# | ftp_write         |
# | multihop          |
# | rootkit           |
# | buffer_overflow   |
# | imap              |
# | warezmaster       |
# | phf               |
# | land              |
# | loadmodule        |
# | spy               |
#
#
# ****** Label distribution in the dataset *****
#
# normal             13448
# neptune             8282
# ipsweep              710
# satan                691
# portsweep            587
# smurf                529
# nmap                 301
# back                 196
# teardrop             188
# warezclient          181
# pod                   38
# guess_passwd          10
# warezmaster            7
# buffer_overflow        6
# imap                   5
# rootkit                4
# phf                    2
# multihop               2
# land                   1
# ftp_write              1
# spy                    1
# loadmodule             1
# Name: attack_type, dtype: int64
#
#
# ***** End checking the statistics of the dataSet *****
#
# ***** Here is how to training dataset looks like before performing any pre-processing *****
#    Duration Protocol_type  Service Flag  Src_bytes  Dst_bytes  Land  \
# 0         0           udp    other   SF        146          0     0
# 1         0           tcp  private   S0          0          0     0
# 2         0           tcp     http   SF        232       8153     0
# 3         0           tcp     http   SF        199        420     0
# 4         0           tcp  private  REJ          0          0     0
#
#    Wrong_fragment  Urgent  Hot  ...  Dst_host_srv_count  \
# 0               0       0    0  ...                   1
# 1               0       0    0  ...                  26
# 2               0       0    0  ...                 255
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                  19
#
#    Dst_host_same_srv_rate  Dst_host_diff_srv_rate  \
# 0                    0.00                    0.60
# 1                    0.10                    0.05
# 2                    1.00                    0.00
# 3                    1.00                    0.00
# 4                    0.07                    0.07
#
#    Dst_host_same_src_port_rate  Dst_host_srv_diff_host_rate  \
# 0                         0.88                         0.00
# 1                         0.00                         0.00
# 2                         0.03                         0.04
# 3                         0.00                         0.00
# 4                         0.00                         0.00
#
#    Dst_host_serror_rate  Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                  0.00                      0.00                   0.0
# 1                  1.00                      1.00                   0.0
# 2                  0.03                      0.01                   0.0
# 3                  0.00                      0.00                   0.0
# 4                  0.00                      0.00                   1.0
#
#    Dst_host_srv_rerror_rate  attack_type
# 0                      0.00       normal
# 1                      0.00      neptune
# 2                      0.01       normal
# 3                      0.00       normal
# 4                      1.00      neptune
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Load the testing dataset and check the statistics

# %%
#Define file names and call loadCSV to load the CSV files
testingDataSet = loadCSV(testingFileNameWithAbsolutePath)
difficultyLevel = testingDataSet.pop('difficulty_level')

#Look at the statistics of the dataSet
getStatisticsOfData(testingDataSet)
print("\n***** Here is how to testing dataset looks like before performing any pre-processing *****")
testingDataSet.head()
# Out:
# ***** Start checking the statistics of the dataSet *****
#
# ***** Shape (number of rows and columns) in the dataset:  (11850, 42)
# ***** Total number of features in the dataset:  41
# ***** Number of categorical features in the dataset:  3
# ***** Number of numerical features in the dataset:  38
#
# ***** Names of categorical features in dataset *****
#
# | Categorical features in dataset   |
# |-----------------------------------|
# | Protocol_type                     |
# | Flag                              |
# | Service                           |
#
#
# ***** Names of numerical features in dataset *****
#
# | Numerical features in the dataset   |
# |-------------------------------------|
# | Duration                            |
# | Src_bytes                           |
# | Dst_bytes                           |
# | Land                                |
# | Wrong_fragment                      |
# | Urgent                              |
# | Hot                                 |
# | Num_failed_logins                   |
# | Logged_in                           |
# | Num_compromised                     |
# | Root_shell                          |
# | Su_attempted                        |
# | Num_root                            |
# | Num_file_creations                  |
# | Num_shells                          |
# | Num_access_files                    |
# | Num_outbound_cmds                   |
# | Is_hot_login                        |
# | Is_guest_login                      |
# | Count                               |
# | Srv_count                           |
# | Serror_rate                         |
# | Srv_serror_rate                     |
# | Rerror_rate                         |
# | Srv_rerror_rate                     |
# | Same_srv_rate                       |
# | Diff_srv_rate                       |
# | Srv_diff_host_rate                  |
# | Dst_host_count                      |
# | Dst_host_srv_count                  |
# | Dst_host_same_srv_rate              |
# | Dst_host_diff_srv_rate              |
# | Dst_host_same_src_port_rate         |
# | Dst_host_srv_diff_host_rate         |
# | Dst_host_serror_rate                |
# | Dst_host_srv_serror_rate            |
# | Dst_host_rerror_rate                |
# | Dst_host_srv_rerror_rate            |
#
#
# ***** Are there any missing values in the data set:  False
# Total number of records in the dataset: 11850
# Unique records in the dataset: 11850
#
# ***** Are there any duplicate records in the data set:  False
#
# ****** Number of different values for label that are present in the dataset:  38
#
# ****** Here is the list of unique label types present in the dataset *****
#
# | Unique label types in the dataset   |
# |-------------------------------------|
# | guess_passwd                        |
# | snmpguess                           |
# | processtable                        |
# | normal                              |
# | nmap                                |
# | back                                |
# | neptune                             |
# | satan                               |
# | saint                               |
# | mscan                               |
# | apache2                             |
# | httptunnel                          |
# | warezmaster                         |
# | ipsweep                             |
# | smurf                               |
# | mailbomb                            |
# | teardrop                            |
# | portsweep                           |
# | snmpgetattack                       |
# | multihop                            |
# | worm                                |
# | land                                |
# | sendmail                            |
# | buffer_overflow                     |
# | pod                                 |
# | rootkit                             |
# | xlock                               |
# | xterm                               |
# | xsnoop                              |
# | ps                                  |
# | named                               |
# | ftp_write                           |
# | loadmodule                          |
# | phf                                 |
# | udpstorm                            |
# | perl                                |
# | sqlattack                           |
# | imap                                |
#
#
# ****** Here is the list of unique values present in each categorical feature in the dataset *****
#
#
# Service: 62
# | distinct values   |
# |-------------------|
# | telnet            |
# | private           |
# | http              |
# | imap4             |
# | ftp_data          |
# | other             |
# | ctf               |
# | pop_3             |
# | ftp               |
# | domain_u          |
# | domain            |
# | eco_i             |
# | ecr_i             |
# | finger            |
# | name              |
# | smtp              |
# | vmnet             |
# | mtp               |
# | bgp               |
# | exec              |
# | sunrpc            |
# | uucp_path         |
# | iso_tsap          |
# | echo              |
# | auth              |
# | hostnames         |
# | courier           |
# | uucp              |
# | daytime           |
# | nntp              |
# | netstat           |
# | urp_i             |
# | http_443          |
# | csnet_ns          |
# | login             |
# | klogin            |
# | whois             |
# | time              |
# | link              |
# | discard           |
# | gopher            |
# | supdup            |
# | netbios_ns        |
# | systat            |
# | netbios_dgm       |
# | kshell            |
# | efs               |
# | nnsp              |
# | ssh               |
# | netbios_ssn       |
# | Z39_50            |
# | IRC               |
# | ntp_u             |
# | X11               |
# | pm_dump           |
# | ldap              |
# | remote_job        |
# | sql_net           |
# | shell             |
# | tim_i             |
# | pop_2             |
# | tftp_u            |
#
#
# Protocol_type: 3
# | distinct values   |
# |-------------------|
# | tcp               |
# | udp               |
# | icmp              |
#
#
# Flag: 11
# | distinct values   |
# |-------------------|
# | SF                |
# | S3                |
# | SH                |
# | REJ               |
# | S0                |
# | RSTO              |
# | RSTR              |
# | RSTOS0            |
# | S1                |
# | S2                |
# | OTH               |
#
#
# attack_type: 38
# | distinct values   |
# |-------------------|
# | guess_passwd      |
# | snmpguess         |
# | processtable      |
# | normal            |
# | nmap              |
# | back              |
# | neptune           |
# | satan             |
# | saint             |
# | mscan             |
# | apache2           |
# | httptunnel        |
# | warezmaster       |
# | ipsweep           |
# | smurf             |
# | mailbomb          |
# | teardrop          |
# | portsweep         |
# | snmpgetattack     |
# | multihop          |
# | worm              |
# | land              |
# | sendmail          |
# | buffer_overflow   |
# | pod               |
# | rootkit           |
# | xlock             |
# | xterm             |
# | xsnoop            |
# | ps                |
# | named             |
# | ftp_write         |
# | loadmodule        |
# | phf               |
# | udpstorm          |
# | perl              |
# | sqlattack         |
# | imap              |
#
#
# ****** Label distribution in the dataset *****
#
# normal             2152
# neptune            1579
# guess_passwd       1231
# mscan               996
# warezmaster         944
# apache2             737
# satan               727
# processtable        685
# smurf               627
# back                359
# snmpguess           331
# saint               309
# mailbomb            293
# snmpgetattack       178
# portsweep           156
# ipsweep             141
# httptunnel          133
# nmap                 73
# pod                  41
# buffer_overflow      20
# multihop             18
# named                17
# ps                   15
# sendmail             14
# rootkit              13
# xterm                13
# teardrop             12
# xlock                 9
# land                  7
# xsnoop                4
# ftp_write             3
# loadmodule            2
# udpstorm              2
# phf                   2
# perl                  2
# worm                  2
# sqlattack             2
# imap                  1
# Name: attack_type, dtype: int64
#
#
# ***** End checking the statistics of the dataSet *****
#
# ***** Here is how to testing dataset looks like before performing any pre-processing *****
#    Duration Protocol_type  Service Flag  Src_bytes  Dst_bytes  Land  \
# 0        13           tcp   telnet   SF        118       2425     0
# 1         0           udp  private   SF         44          0     0
# 2         0           tcp   telnet   S3          0         44     0
# 3         0           udp  private   SF         53         55     0
# 4         0           tcp  private   SH          0          0     0
#
#    Wrong_fragment  Urgent  Hot  ...  Dst_host_srv_count  \
# 0               0       0    0  ...                  10
# 1               0       0    0  ...                 254
# 2               0       0    0  ...                  79
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                   1
#
#    Dst_host_same_srv_rate  Dst_host_diff_srv_rate  \
# 0                    0.38                    0.12
# 1                    1.00                    0.01
# 2                    0.31                    0.61
# 3                    1.00                    0.00
# 4                    0.06                    1.00
#
#    Dst_host_same_src_port_rate  Dst_host_srv_diff_host_rate  \
# 0                         0.04                          0.0
# 1                         0.01                          0.0
# 2                         0.00                          0.0
# 3                         0.87                          0.0
# 4                         1.00                          0.0
#
#    Dst_host_serror_rate  Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.12
# 1                  0.00                      0.00                  0.00
# 2                  0.21                      0.68                  0.60
# 3                  0.00                      0.00                  0.00
# 4                  1.00                      1.00                  0.00
#
#    Dst_host_srv_rerror_rate   attack_type
# 0                       0.3  guess_passwd
# 1                       0.0     snmpguess
# 2                       0.0  processtable
# 3                       0.0        normal
# 4                       0.0          nmap
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Perform pre-processing, training, evaluation and persist the models

# %%
arrayOfModels = defineArrayOfModels()
performPreprocessingBuildModelsAndEvaluateAccuracy(trainingDataSet, testingDataSet, arrayOfModels)
# Out:
# [['FeatureSelectionTechnique', 'FeatureEncodingTechnique', 'FeatureNormalizationTechnique', 'ClassificationTechnique', 'TrainAccuraccy', 'TestAccuraccy', 'ModelName', 'ModelFileName'], ['ExtraTreesClassifier', 'OneHotEncoder', 'Standardization', 'DecisonTree'], ['ExtraTreesClassifier', 'OneHotEncoder', 'Standardization', 'RandomForestClassifier'], ['ExtraTreesClassifier', 'OneHotEncoder', 'Standardization', 'ExtraTreesClassifier'], ['ExtraTreesClassifier', 'OneHotEncoder', 'Standardization', 'KNN']]
# ***************************************************************************************************************************
# ********************************************* Building Model- 1  As Below *************************************************
# 	 -- Feature Selection: 	  ExtraTreesClassifier
# 	 -- Feature Encoding: 	  OneHotEncoder
# 	 -- Feature Scaling: 	  Standardization
# 	 -- Classification: 	  DecisonTree
#
# completeDataSet.shape:  (37041, 43)
# completeDataSet.head:     Duration Protocol_type  Service Flag  Src_bytes  Dst_bytes  Land  \
# 0         0           udp    other   SF        146          0     0
# 1         0           tcp  private   S0          0          0     0
# 2         0           tcp     http   SF        232       8153     0
# 3         0           tcp     http   SF        199        420     0
# 4         0           tcp  private  REJ          0          0     0
#
#    Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.00
# 1               0       0    0  ...                    0.10
# 2               0       0    0  ...                    1.00
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    0.07
#
#    Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                    0.60                         0.88
# 1                    0.05                         0.00
# 2                    0.00                         0.03
# 3                    0.00                         0.00
# 4                    0.07                         0.00
#
#    Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  1.00
# 2                         0.04                  0.03
# 3                         0.00                  0.00
# 4                         0.00                  0.00
#
#    Dst_host_srv_serror_rate  Dst_host_rerror_rate  Dst_host_srv_rerror_rate  \
# 0                      0.00                   0.0                      0.00
# 1                      1.00                   0.0                      0.00
# 2                      0.01                   0.0                      0.01
# 3                      0.00                   0.0                      0.00
# 4                      0.00                   1.0                      1.00
#
#    attack_type  difficulty_level
# 0       normal                15
# 1      neptune                19
# 2       normal                21
# 3       normal                21
# 4      neptune                21
#
# [5 rows x 43 columns]
#
# ****** Start performing feature selection using ExtraTreesClassifier *****
# ****** Falls under wrapper methods (feature importance) *****
# ****** Start label encoding on the categorical features in the given dataset *****
# ****** Number of features before label encoding:  43
# ****** Number of categorical features in the dataset:  3
# ****** Categorical feature names in the dataset:  ['Protocol_type' 'Service' 'Flag']
#
# ****** Here is the list of unique values present in each categorical feature in the dataset *****
#
#
# Protocol_type: 3
# | distinct values   |
# |-------------------|
# | udp               |
# | tcp               |
# | icmp              |
#
#
# Service: 67
# | distinct values   |
# |-------------------|
# | other             |
# | private           |
# | http              |
# | remote_job        |
# | ftp_data          |
# | name              |
# | netbios_ns        |
# | eco_i             |
# | mtp               |
# | telnet            |
# | finger            |
# | domain_u          |
# | supdup            |
# | uucp_path         |
# | Z39_50            |
# | smtp              |
# | csnet_ns          |
# | uucp              |
# | netbios_dgm       |
# | urp_i             |
# | auth              |
# | domain            |
# | ftp               |
# | bgp               |
# | ldap              |
# | ecr_i             |
# | gopher            |
# | vmnet             |
# | systat            |
# | http_443          |
# | efs               |
# | whois             |
# | imap4             |
# | iso_tsap          |
# | echo              |
# | klogin            |
# | link              |
# | sunrpc            |
# | login             |
# | kshell            |
# | sql_net           |
# | time              |
# | hostnames         |
# | exec              |
# | ntp_u             |
# | discard           |
# | nntp              |
# | courier           |
# | ctf               |
# | ssh               |
# | daytime           |
# | shell             |
# | netstat           |
# | pop_3             |
# | nnsp              |
# | IRC               |
# | pop_2             |
# | printer           |
# | tim_i             |
# | pm_dump           |
# | red_i             |
# | netbios_ssn       |
# | rje               |
# | X11               |
# | urh_i             |
# | http_8001         |
# | tftp_u            |
#
#
# Flag: 11
# | distinct values   |
# |-------------------|
# | SF                |
# | S0                |
# | REJ               |
# | RSTR              |
# | SH                |
# | RSTO              |
# | S1                |
# | RSTOS0            |
# | S3                |
# | S2                |
# | OTH               |
#
# ****** Number of features after label encoding:  43
# ****** End label encoding on the categorical features in the given dataset *****
#
# ****** ExtraTreesClassification is in progress *****
#
#  selectedFeatures after ExtraTreesClassification:  Same_srv_rate                  0.079814
# difficulty_level               0.075030
# Dst_host_srv_serror_rate       0.050092
# Service                        0.047946
# Dst_host_serror_rate           0.046506
# Flag                           0.046046
# Dst_host_same_srv_rate         0.041192
# Protocol_type                  0.040277
# Dst_host_srv_count             0.039453
# Serror_rate                    0.038830
# Dst_host_same_src_port_rate    0.038704
# Srv_serror_rate                0.038174
# Logged_in                      0.035642
# Count                          0.034191
# Dst_host_rerror_rate           0.030793
# Diff_srv_rate                  0.030209
# Src_bytes                      0.029196
# Dst_host_diff_srv_rate         0.028981
# Dst_host_count                 0.026592
# Rerror_rate                    0.024637
# dtype: float64
# ****** Completed ExtraTreesClassification *****
#
# ***** Number of columns in the dataSet after feature selection:  21
# ***** Columns in the dataSet after feature selection:
#  Index(['Protocol_type', 'Service', 'Flag', 'Src_bytes', 'Logged_in', 'Count',
#        'Serror_rate', 'Srv_serror_rate', 'Rerror_rate', 'Same_srv_rate',
#        'Diff_srv_rate', 'Dst_host_count', 'Dst_host_srv_count',
#        'Dst_host_same_srv_rate', 'Dst_host_diff_srv_rate',
#        'Dst_host_same_src_port_rate', 'Dst_host_serror_rate',
#        'Dst_host_srv_serror_rate', 'Dst_host_rerror_rate', 'difficulty_level',
#        'attack_type'],
#       dtype='object')
# ****** End performing feature selection using ExtraTreesClassifier *****
# ****** Start one hot encoding on the categorical features in the given dataset *****
# ****** Number of features before one hot encoding:  21
# ****** Number of categorical features in the dataset:  0
# ****** Categorical feature names in the dataset:  []
#
# ****** Here is the list of unique values present in each categorical feature in the dataset *****
#
#
# attack_type: 40
# | distinct values   |
# |-------------------|
# | normal            |
# | neptune           |
# | warezclient       |
# | ipsweep           |
# | portsweep         |
# | teardrop          |
# | nmap              |
# | satan             |
# | smurf             |
# | pod               |
# | back              |
# | guess_passwd      |
# | ftp_write         |
# | multihop          |
# | rootkit           |
# | buffer_overflow   |
# | imap              |
# | warezmaster       |
# | phf               |
# | land              |
# | loadmodule        |
# | spy               |
# | snmpguess         |
# | processtable      |
# | saint             |
# | mscan             |
# | apache2           |
# | httptunnel        |
# | mailbomb          |
# | snmpgetattack     |
# | worm              |
# | sendmail          |
# | xlock             |
# | xterm             |
# | xsnoop            |
# | ps                |
# | named             |
# | udpstorm          |
# | perl              |
# | sqlattack         |
#
# ****** Number of features after one hot encoding:  21
# ****** End one hot encoding on the categorical features in the given dataset *****
#
# ****** Start feature scaling of the features present in the dataset using StandardScalar *****
# [[2 41 9 ... 0.0 15 'normal']
#  [1 46 5 ... 0.0 19 'neptune']
#  [1 22 9 ... 0.0 21 'normal']
#  ...
#  [1 57 2 ... 0.85 13 'mscan']
#  [1 54 1 ... 0.88 15 'mscan']
#  [2 46 9 ... 0.0 17 'snmpguess']]
#
# ****** Number of features in the dataset before performing scaling:  20
#
# ****** Features in the dataset before performing scaling *****
#  [[2 41 9 ... 0.0 0.0 15]
#  [1 46 5 ... 1.0 0.0 19]
#  [1 22 9 ... 0.01 0.0 21]
#  ...
#  [1 57 2 ... 0.08 0.85 13]
#  [1 54 1 ... 0.0 0.88 15]
#  [2 46 9 ... 0.0 0.0 17]]
#
# ****** Number of features in the dataset after performing scaling:  20
#
# ****** Features in the dataset after performing scaling *****
#  [[ 2.03857058  0.6299765   0.73536923 ... -0.54981386 -0.48776502
#   -0.85380057]
#  [-0.15478617  0.93890397 -0.66099165 ...  1.89967409 -0.48776502
#    0.22813874]
#  [-0.15478617 -0.54394786  0.73536923 ... -0.52531898 -0.48776502
#    0.76910839]
#  ...
#  [-0.15478617  1.61854439 -1.70826232 ... -0.35385482  2.03171007
#   -1.39477022]
#  [-0.15478617  1.43318791 -2.05735254 ... -0.54981386  2.12063272
#   -0.85380057]
#  [ 2.03857058  0.93890397  0.73536923 ... -0.54981386 -0.48776502
#   -0.31283092]]
# scaledFeatures.head():     Protocol_type   Service      Flag  Src_bytes  Logged_in     Count  \
# 0       2.038571  0.629977  0.735369  -0.011190  -0.732914 -0.581217
# 1      -0.154786  0.938904 -0.660992  -0.011262  -0.732914  0.275339
# 2      -0.154786 -0.543948  0.735369  -0.011147   1.364417 -0.643512
# 3      -0.154786 -0.543948  0.735369  -0.011163   1.364417 -0.448840
# 4      -0.154786  0.938904 -2.057353  -0.011262  -0.732914  0.259766
#
#    Serror_rate  Srv_serror_rate  Rerror_rate  Same_srv_rate  ...  \
# 0    -0.556584        -0.552030    -0.460806      -1.421427  ...
# 1     1.851192         1.851769    -0.460806      -1.491319  ...
# 2    -0.075029        -0.071270    -0.460806       0.721924  ...
# 3    -0.556584        -0.552030    -0.460806       0.721924  ...
# 4    -0.556584        -0.552030     2.274941      -1.235049  ...
#
#    Dst_host_count  Dst_host_srv_count  Dst_host_same_srv_rate  \
# 0        0.656445           -1.050270               -1.193023
# 1        0.656445           -0.821669               -0.966271
# 2       -1.709884            1.272317                1.074493
# 3        0.656445            1.272317                1.074493
# 4        0.656445           -0.885678               -1.034297
#
#    Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  Dst_host_serror_rate  \
# 0                2.187298                     2.137976             -0.561390
# 1               -0.237144                    -0.498320              1.904034
# 2               -0.457548                    -0.408446             -0.487427
# 3               -0.457548                    -0.498320             -0.561390
# 4               -0.148983                    -0.498320             -0.561390
#
#    Dst_host_srv_serror_rate  Dst_host_rerror_rate  difficulty_level  \
# 0                 -0.549814             -0.487765         -0.853801
# 1                  1.899674             -0.487765          0.228139
# 2                 -0.525319             -0.487765          0.769108
# 3                 -0.549814             -0.487765          0.769108
# 4                 -0.549814              2.476323          0.769108
#
#    attack_type
# 0       normal
# 1      neptune
# 2       normal
# 3       normal
# 4      neptune
#
# [5 rows x 21 columns]
# scaledFeatures.shape:  (37041, 21)
#
# ****** End of feature scaling of the features present in the dataset using StandardScalar *****
#
# features.shape:  (37041, 20)
# label.shape:  (37041,)
# ****** Start classification training using DecisionTreeClassifier *****
# *** Classification accuracy score during model training:  0.9987401007919366
# *** Classification accuracy score during model testing:  0.8164270770061416
#
# ****** End classification training using DecisionTreeClassifier *****
#
# ***************************************************************************************************************************
# ********************************************* Building Model- 2  As Below *************************************************
# 	 -- Feature Selection: 	  ExtraTreesClassifier
# 	 -- Feature Encoding: 	  OneHotEncoder
# 	 -- Feature Scaling: 	  Standardization
# 	 -- Classification: 	  RandomForestClassifier
#
# completeDataSet.shape:  (37041, 43)
# completeDataSet.head:     Duration Protocol_type  Service Flag  Src_bytes  Dst_bytes  Land  \
# 0         0           udp    other   SF        146          0     0
# 1         0           tcp  private   S0          0          0     0
# 2         0           tcp     http   SF        232       8153     0
# 3         0           tcp     http   SF        199        420     0
# 4         0           tcp  private  REJ          0          0     0
#
#    Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.00
# 1               0       0    0  ...                    0.10
# 2               0       0    0  ...                    1.00
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    0.07
#
#    Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                    0.60                         0.88
# 1                    0.05                         0.00
# 2                    0.00                         0.03
# 3                    0.00                         0.00
# 4                    0.07                         0.00
#
#    Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  1.00
# 2                         0.04                  0.03
# 3                         0.00                  0.00
# 4                         0.00                  0.00
#
#    Dst_host_srv_serror_rate  Dst_host_rerror_rate  Dst_host_srv_rerror_rate  \
# 0                      0.00                   0.0                      0.00
# 1                      1.00                   0.0                      0.00
# 2                      0.01                   0.0                      0.01
# 3                      0.00                   0.0                      0.00
# 4                      0.00                   1.0                      1.00
#
#    attack_type  difficulty_level
# 0       normal                15
# 1      neptune                19
# 2       normal                21
# 3       normal                21
# 4      neptune                21
#
# [5 rows x 43 columns]
#
# ****** Start performing feature selection using ExtraTreesClassifier *****
# ****** Falls under wrapper methods (feature importance) *****
# ****** Start label encoding on the categorical features in the given dataset *****
# ****** Number of features before label encoding:  43
# ****** Number of categorical features in the dataset:  3
# ****** Categorical feature names in the dataset:  ['Protocol_type' 'Service' 'Flag']
#
# ****** Here is the list of unique values present in each categorical feature in the dataset *****
#
#
# Protocol_type: 3
# | distinct values   |
# |-------------------|
# | udp               |
# | tcp               |
# | icmp              |
#
#
# Service: 67
# | distinct values   |
# |-------------------|
# | other             |
# | private           |
# | http              |
# | remote_job        |
# | ftp_data          |
# | name              |
# | netbios_ns        |
# | eco_i             |
# | mtp               |
# | telnet            |
# | finger            |
# | domain_u          |
# | supdup            |
# | uucp_path         |
# | Z39_50            |
# | smtp              |
# | csnet_ns          |
# | uucp              |
# | netbios_dgm       |
# | urp_i             |
# | auth              |
# | domain            |
# | ftp               |
# | bgp               |
# | ldap              |
# | ecr_i             |
# | gopher            |
# | vmnet             |
# | systat            |
# | http_443          |
# | efs               |
# | whois             |
# | imap4             |
# | iso_tsap          |
# | echo              |
# | klogin            |
# | link              |
# | sunrpc            |
# | login             |
# | kshell            |
# | sql_net           |
# | time              |
# | hostnames         |
# | exec              |
# | ntp_u             |
# | discard           |
# | nntp              |
# | courier           |
# | ctf               |
# | ssh               |
# | daytime           |
# | shell             |
# | netstat           |
# | pop_3             |
# | nnsp              |
# | IRC               |
# | pop_2             |
# | printer           |
# | tim_i             |
# | pm_dump           |
# | red_i             |
# | netbios_ssn       |
# | rje               |
# | X11               |
# | urh_i             |
# | http_8001         |
# | tftp_u            |
#
#
# Flag: 11
# | distinct values   |
# |-------------------|
# | SF                |
# | S0                |
# | REJ               |
# | RSTR              |
# | SH                |
# | RSTO              |
# | S1                |
# | RSTOS0            |
# | S3                |
# | S2                |
# | OTH               |
#
# ****** Number of features after label encoding:  43
# ****** End label encoding on the categorical features in the given dataset *****
#
# ****** ExtraTreesClassification is in progress *****
#
#  selectedFeatures after ExtraTreesClassification:  Same_srv_rate                  0.075620
# difficulty_level               0.074830
# Dst_host_serror_rate           0.053036
# Service                        0.048764
# Dst_host_srv_serror_rate       0.046249
# Flag                           0.044981
# Dst_host_same_srv_rate         0.043919
# Dst_host_srv_count             0.042541
# Protocol_type                  0.040565
# Serror_rate                    0.040158
# Srv_serror_rate                0.039034
# Dst_host_same_src_port_rate    0.036905
# Logged_in                      0.034609
# Count                          0.033706
# Dst_host_rerror_rate           0.030653
# Dst_host_diff_srv_rate         0.029575
# Src_bytes                      0.028241
# Dst_host_count                 0.028158
# Diff_srv_rate                  0.026258
# dtype: float64
# ****** Completed ExtraTreesClassification *****
#
# ***** Number of columns in the dataSet after feature selection:  20
# ***** Columns in the dataSet after feature selection:
#  Index(['Protocol_type', 'Service', 'Flag', 'Src_bytes', 'Logged_in', 'Count',
#        'Serror_rate', 'Srv_serror_rate', 'Same_srv_rate', 'Diff_srv_rate',
#        'Dst_host_count', 'Dst_host_srv_count', 'Dst_host_same_srv_rate',
#        'Dst_host_diff_srv_rate', 'Dst_host_same_src_port_rate',
#        'Dst_host_serror_rate', 'Dst_host_srv_serror_rate',
#        'Dst_host_rerror_rate', 'difficulty_level', 'attack_type'],
#       dtype='object')
# ****** End performing feature selection using ExtraTreesClassifier *****
# ****** Start one hot encoding on the categorical features in the given dataset *****
# ****** Number of features before one hot encoding:  20
# ****** Number of categorical features in the dataset:  0
# ****** Categorical feature names in the dataset:  []
#
# ****** Here is the list of unique values present in each categorical feature in the dataset *****
#
#
# attack_type: 40
# | distinct values   |
# |-------------------|
# | normal            |
# | neptune           |
# | warezclient       |
# | ipsweep           |
# | portsweep         |
# | teardrop          |
# | nmap              |
# | satan             |
# | smurf             |
# | pod               |
# | back              |
# | guess_passwd      |
# | ftp_write         |
# | multihop          |
# | rootkit           |
# | buffer_overflow   |
# | imap              |
# | warezmaster       |
# | phf               |
# | land              |
# | loadmodule        |
# | spy               |
# | snmpguess         |
# | processtable      |
# | saint             |
# | mscan             |
# | apache2           |
# | httptunnel        |
# | mailbomb          |
# | snmpgetattack     |
# | worm              |
# | sendmail          |
# | xlock             |
# | xterm             |
# | xsnoop            |
# | ps                |
# | named             |
# | udpstorm          |
# | perl              |
# | sqlattack         |
#
# ****** Number of features after one hot encoding:  20
# ****** End one hot encoding on the categorical features in the given dataset *****
#
# ****** Start feature scaling of the features present in the dataset using StandardScalar *****
# [[2 41 9 ... 0.0 15 'normal']
#  [1 46 5 ... 0.0 19 'neptune']
#  [1 22 9 ... 0.0 21 'normal']
#  ...
#  [1 57 2 ... 0.85 13 'mscan']
#  [1 54 1 ... 0.88 15 'mscan']
#  [2 46 9 ... 0.0 17 'snmpguess']]
#
# ****** Number of features in the dataset before performing scaling:  19
#
# ****** Features in the dataset before performing scaling *****
#  [[2 41 9 ... 0.0 0.0 15]
#  [1 46 5 ... 1.0 0.0 19]
#  [1 22 9 ... 0.01 0.0 21]
#  ...
#  [1 57 2 ... 0.08 0.85 13]
#  [1 54 1 ... 0.0 0.88 15]
#  [2 46 9 ... 0.0 0.0 17]]
#
# ****** Number of features in the dataset after performing scaling:  19
#
# ****** Features in the dataset after performing scaling *****
#  [[ 2.03857058  0.6299765   0.73536923 ... -0.54981386 -0.48776502
#   -0.85380057]
#  [-0.15478617  0.93890397 -0.66099165 ...  1.89967409 -0.48776502
#    0.22813874]
#  [-0.15478617 -0.54394786  0.73536923 ... -0.52531898 -0.48776502
#    0.76910839]
#  ...
#  [-0.15478617  1.61854439 -1.70826232 ... -0.35385482  2.03171007
#   -1.39477022]
#  [-0.15478617  1.43318791 -2.05735254 ... -0.54981386  2.12063272
#   -0.85380057]
#  [ 2.03857058  0.93890397  0.73536923 ... -0.54981386 -0.48776502
#   -0.31283092]]
# scaledFeatures.head():     Protocol_type   Service      Flag  Src_bytes  Logged_in     Count  \
# 0       2.038571  0.629977  0.735369  -0.011190  -0.732914 -0.581217
# 1      -0.154786  0.938904 -0.660992  -0.011262  -0.732914  0.275339
# 2      -0.154786 -0.543948  0.735369  -0.011147   1.364417 -0.643512
# 3      -0.154786 -0.543948  0.735369  -0.011163   1.364417 -0.448840
# 4      -0.154786  0.938904 -2.057353  -0.011262  -0.732914  0.259766
#
#    Serror_rate  Srv_serror_rate  Same_srv_rate  Diff_srv_rate  Dst_host_count  \
# 0    -0.556584        -0.552030      -1.421427       0.233303        0.656445
# 1     1.851192         1.851769      -1.491319      -0.092358        0.656445
# 2    -0.075029        -0.071270       0.721924      -0.377312       -1.709884
# 3    -0.556584        -0.552030       0.721924      -0.377312        0.656445
# 4    -0.556584        -0.552030      -1.235049      -0.133066        0.656445
#
#    Dst_host_srv_count  Dst_host_same_srv_rate  Dst_host_diff_srv_rate  \
# 0           -1.050270               -1.193023                2.187298
# 1           -0.821669               -0.966271               -0.237144
# 2            1.272317                1.074493               -0.457548
# 3            1.272317                1.074493               -0.457548
# 4           -0.885678               -1.034297               -0.148983
#
#    Dst_host_same_src_port_rate  Dst_host_serror_rate  \
# 0                     2.137976             -0.561390
# 1                    -0.498320              1.904034
# 2                    -0.408446             -0.487427
# 3                    -0.498320             -0.561390
# 4                    -0.498320             -0.561390
#
#    Dst_host_srv_serror_rate  Dst_host_rerror_rate  difficulty_level  \
# 0                 -0.549814             -0.487765         -0.853801
# 1                  1.899674             -0.487765          0.228139
# 2                 -0.525319             -0.487765          0.769108
# 3                 -0.549814             -0.487765          0.769108
# 4                 -0.549814              2.476323          0.769108
#
#   attack_type
# 0      normal
# 1     neptune
# 2      normal
# 3      normal
# 4     neptune
# scaledFeatures.shape:  (37041, 20)
#
# ****** End of feature scaling of the features present in the dataset using StandardScalar *****
#
# features.shape:  (37041, 19)
# label.shape:  (37041,)
# ****** Start classification training using RandomForestClassifier *****
# *** Classification accuracy score during model training:  0.9987401007919366
# *** Classification accuracy score during model testing:  0.8210164000809881
#
# ****** End classification training using RandomForestClassifier *****
#
# ***************************************************************************************************************************
# ********************************************* Building Model- 3  As Below *************************************************
# 	 -- Feature Selection: 	  ExtraTreesClassifier
# 	 -- Feature Encoding: 	  OneHotEncoder
# 	 -- Feature Scaling: 	  Standardization
# 	 -- Classification: 	  ExtraTreesClassifier
#
# completeDataSet.shape:  (37041, 43)
# completeDataSet.head:     Duration Protocol_type  Service Flag  Src_bytes  Dst_bytes  Land  \
# 0         0           udp    other   SF        146          0     0
# 1         0           tcp  private   S0          0          0     0
# 2         0           tcp     http   SF        232       8153     0
# 3         0           tcp     http   SF        199        420     0
# 4         0           tcp  private  REJ          0          0     0
#
#    Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.00
# 1               0       0    0  ...                    0.10
# 2               0       0    0  ...                    1.00
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    0.07
#
#    Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                    0.60                         0.88
# 1                    0.05                         0.00
# 2                    0.00                         0.03
# 3                    0.00                         0.00
# 4                    0.07                         0.00
#
#    Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  1.00
# 2                         0.04                  0.03
# 3                         0.00                  0.00
# 4                         0.00                  0.00
#
#    Dst_host_srv_serror_rate  Dst_host_rerror_rate  Dst_host_srv_rerror_rate  \
# 0                      0.00                   0.0                      0.00
# 1                      1.00                   0.0                      0.00
# 2                      0.01                   0.0                      0.01
# 3                      0.00                   0.0                      0.00
# 4                      0.00                   1.0                      1.00
#
#    attack_type  difficulty_level
# 0       normal                15
# 1      neptune                19
# 2       normal                21
# 3       normal                21
# 4      neptune                21
#
# [5 rows x 43 columns]
#
# ****** Start performing feature selection using ExtraTreesClassifier *****
# ****** Falls under wrapper methods (feature importance) *****
# ****** Start label encoding on the categorical features in the given dataset *****
# ****** Number of features before label encoding:  43
# ****** Number of categorical features in the dataset:  3
# ****** Categorical feature names in the dataset:  ['Protocol_type' 'Service' 'Flag']
#
# ****** Here is the list of unique values present in each categorical feature in the dataset *****
#
#
# Protocol_type: 3
# | distinct values   |
# |-------------------|
# | udp               |
# | tcp               |
# | icmp              |
#
#
# Service: 67
# | distinct values   |
# |-------------------|
# | other             |
# | private           |
# | http              |
# | remote_job        |
# | ftp_data          |
# | name              |
# | netbios_ns        |
# | eco_i             |
# | mtp               |
# | telnet            |
# | finger            |
# | domain_u          |
# | supdup            |
# | uucp_path         |
# | Z39_50            |
# | smtp              |
# | csnet_ns          |
# | uucp              |
# | netbios_dgm       |
# | urp_i             |
# | auth              |
# | domain            |
# | ftp               |
# | bgp               |
# | ldap              |
# | ecr_i             |
# | gopher            |
# | vmnet             |
# | systat            |
# | http_443          |
# | efs               |
# | whois             |
# | imap4             |
# | iso_tsap          |
# | echo              |
# | klogin            |
# | link              |
# | sunrpc            |
# | login             |
# | kshell            |
# | sql_net           |
# | time              |
# | hostnames         |
# | exec              |
# | ntp_u             |
# | discard           |
# | nntp              |
# | courier           |
# | ctf               |
# | ssh               |
# | daytime           |
# | shell             |
# | netstat           |
# | pop_3             |
# | nnsp              |
# | IRC               |
# | pop_2             |
# | printer           |
# | tim_i             |
# | pm_dump           |
# | red_i             |
# | netbios_ssn       |
# | rje               |
# | X11               |
# | urh_i             |
# | http_8001         |
# | tftp_u            |
#
#
# Flag: 11
# | distinct values   |
# |-------------------|
# | SF                |
# | S0                |
# | REJ               |
# | RSTR              |
# | SH                |
# | RSTO              |
# | S1                |
# | RSTOS0            |
# | S3                |
# | S2                |
# | OTH               |
#
# ****** Number of features after label encoding:  43
# ****** End label encoding on the categorical features in the given dataset *****
#
# ****** ExtraTreesClassification is in progress *****
#
#  selectedFeatures after ExtraTreesClassification:  difficulty_level               0.075589
# Same_srv_rate                  0.069718
# Dst_host_srv_serror_rate       0.050615
# Service                        0.048118
# Dst_host_serror_rate           0.047601
# Flag                           0.046145
# Dst_host_same_srv_rate         0.044551
# Serror_rate                    0.043654
# Protocol_type                  0.040770
# Srv_serror_rate                0.040029
# Dst_host_srv_count             0.039024
# Dst_host_same_src_port_rate    0.037854
# Logged_in                      0.035737
# Count                          0.034763
# Dst_host_rerror_rate           0.031640
# Dst_host_diff_srv_rate         0.028806
# Src_bytes                      0.028422
# Dst_host_count                 0.027371
# Diff_srv_rate                  0.026502
# dtype: float64
# ****** Completed ExtraTreesClassification *****
#
# ***** Number of columns in the dataSet after feature selection:  20
# ***** Columns in the dataSet after feature selection:
#  Index(['Protocol_type', 'Service', 'Flag', 'Src_bytes', 'Logged_in', 'Count',
#        'Serror_rate', 'Srv_serror_rate', 'Same_srv_rate', 'Diff_srv_rate',
#        'Dst_host_count', 'Dst_host_srv_count', 'Dst_host_same_srv_rate',
#        'Dst_host_diff_srv_rate', 'Dst_host_same_src_port_rate',
#        'Dst_host_serror_rate', 'Dst_host_srv_serror_rate',
#        'Dst_host_rerror_rate', 'difficulty_level', 'attack_type'],
#       dtype='object')
# ****** End performing feature selection using ExtraTreesClassifier *****
# ****** Start one hot encoding on the categorical features in the given dataset *****
# ****** Number of features before one hot encoding:  20
# ****** Number of categorical features in the dataset:  0
# ****** Categorical feature names in the dataset:  []
#
# ****** Here is the list of unique values present in each categorical feature in the dataset *****
#
#
# attack_type: 40
# | distinct values   |
# |-------------------|
# | normal            |
# | neptune           |
# | warezclient       |
# | ipsweep           |
# | portsweep         |
# | teardrop          |
# | nmap              |
# | satan             |
# | smurf             |
# | pod               |
# | back              |
# | guess_passwd      |
# | ftp_write         |
# | multihop          |
# | rootkit           |
# | buffer_overflow   |
# | imap              |
# | warezmaster       |
# | phf               |
# | land              |
# | loadmodule        |
# | spy               |
# | snmpguess         |
# | processtable      |
# | saint             |
# | mscan             |
# | apache2           |
# | httptunnel        |
# | mailbomb          |
# | snmpgetattack     |
# | worm              |
# | sendmail          |
# | xlock             |
# | xterm             |
# | xsnoop            |
# | ps                |
# | named             |
# | udpstorm          |
# | perl              |
# | sqlattack         |
#
# ****** Number of features after one hot encoding:  20
# ****** End one hot encoding on the categorical features in the given dataset *****
#
# ****** Start feature scaling of the features present in the dataset using StandardScalar *****
# [[2 41 9 ... 0.0 15 'normal']
#  [1 46 5 ... 0.0 19 'neptune']
#  [1 22 9 ... 0.0 21 'normal']
#  ...
#  [1 57 2 ... 0.85 13 'mscan']
#  [1 54 1 ... 0.88 15 'mscan']
#  [2 46 9 ... 0.0 17 'snmpguess']]
#
# ****** Number of features in the dataset before performing scaling:  19
#
# ****** Features in the dataset before performing scaling *****
#  [[2 41 9 ... 0.0 0.0 15]
#  [1 46 5 ... 1.0 0.0 19]
#  [1 22 9 ... 0.01 0.0 21]
#  ...
#  [1 57 2 ... 0.08 0.85 13]
#  [1 54 1 ... 0.0 0.88 15]
#  [2 46 9 ... 0.0 0.0 17]]
#
# ****** Number of features in the dataset after performing scaling:  19
#
# ****** Features in the dataset after performing scaling *****
#  [[ 2.03857058  0.6299765   0.73536923 ... -0.54981386 -0.48776502
#   -0.85380057]
#  [-0.15478617  0.93890397 -0.66099165 ...  1.89967409 -0.48776502
#    0.22813874]
#  [-0.15478617 -0.54394786  0.73536923 ... -0.52531898 -0.48776502
#    0.76910839]
#  ...
#  [-0.15478617  1.61854439 -1.70826232 ... -0.35385482  2.03171007
#   -1.39477022]
#  [-0.15478617  1.43318791 -2.05735254 ... -0.54981386  2.12063272
#   -0.85380057]
#  [ 2.03857058  0.93890397  0.73536923 ... -0.54981386 -0.48776502
#   -0.31283092]]
# scaledFeatures.head():     Protocol_type   Service      Flag  Src_bytes  Logged_in     Count  \
# 0       2.038571  0.629977  0.735369  -0.011190  -0.732914 -0.581217
# 1      -0.154786  0.938904 -0.660992  -0.011262  -0.732914  0.275339
# 2      -0.154786 -0.543948  0.735369  -0.011147   1.364417 -0.643512
# 3      -0.154786 -0.543948  0.735369  -0.011163   1.364417 -0.448840
# 4      -0.154786  0.938904 -2.057353  -0.011262  -0.732914  0.259766
#
#    Serror_rate  Srv_serror_rate  Same_srv_rate  Diff_srv_rate  Dst_host_count  \
# 0    -0.556584        -0.552030      -1.421427       0.233303        0.656445
# 1     1.851192         1.851769      -1.491319      -0.092358        0.656445
# 2    -0.075029        -0.071270       0.721924      -0.377312       -1.709884
# 3    -0.556584        -0.552030       0.721924      -0.377312        0.656445
# 4    -0.556584        -0.552030      -1.235049      -0.133066        0.656445
#
#    Dst_host_srv_count  Dst_host_same_srv_rate  Dst_host_diff_srv_rate  \
# 0           -1.050270               -1.193023                2.187298
# 1           -0.821669               -0.966271               -0.237144
# 2            1.272317                1.074493               -0.457548
# 3            1.272317                1.074493               -0.457548
# 4           -0.885678               -1.034297               -0.148983
#
#    Dst_host_same_src_port_rate  Dst_host_serror_rate  \
# 0                     2.137976             -0.561390
# 1                    -0.498320              1.904034
# 2                    -0.408446             -0.487427
# 3                    -0.498320             -0.561390
# 4                    -0.498320             -0.561390
#
#    Dst_host_srv_serror_rate  Dst_host_rerror_rate  difficulty_level  \
# 0                 -0.549814             -0.487765         -0.853801
# 1                  1.899674             -0.487765          0.228139
# 2                 -0.525319             -0.487765          0.769108
# 3                 -0.549814             -0.487765          0.769108
# 4                 -0.549814              2.476323          0.769108
#
#   attack_type
# 0      normal
# 1     neptune
# 2      normal
# 3      normal
# 4     neptune
# scaledFeatures.shape:  (37041, 20)
#
# ****** End of feature scaling of the features present in the dataset using StandardScalar *****
#
# features.shape:  (37041, 19)
# label.shape:  (37041,)
# ****** Start classification training using ExtraTreesClassifier *****
# trainingEncodedAndScaledDataset.shape:  (22224, 20)
# *** Classification accuracy score during model training:  0.9987401007919366
# testingEncodedAndScaledDataset.shape:  (14817, 20)
# *** Classification accuracy score during model testing:  0.8204089896740231
#
# ****** End classification training using ExtraTreesClassifier *****
#
# ***************************************************************************************************************************
# ********************************************* Building Model- 4  As Below *************************************************
# 	 -- Feature Selection: 	  ExtraTreesClassifier
# 	 -- Feature Encoding: 	  OneHotEncoder
# 	 -- Feature Scaling: 	  Standardization
# 	 -- Classification: 	  KNN
#
# completeDataSet.shape:  (37041, 43)
# completeDataSet.head:     Duration Protocol_type  Service Flag  Src_bytes  Dst_bytes  Land  \
# 0         0           udp    other   SF        146          0     0
# 1         0           tcp  private   S0          0          0     0
# 2         0           tcp     http   SF        232       8153     0
# 3         0           tcp     http   SF        199        420     0
# 4         0           tcp  private  REJ          0          0     0
#
#    Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.00
# 1               0       0    0  ...                    0.10
# 2               0       0    0  ...                    1.00
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    0.07
#
#    Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                    0.60                         0.88
# 1                    0.05                         0.00
# 2                    0.00                         0.03
# 3                    0.00                         0.00
# 4                    0.07                         0.00
#
#    Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  1.00
# 2                         0.04                  0.03
# 3                         0.00                  0.00
# 4                         0.00                  0.00
#
#    Dst_host_srv_serror_rate  Dst_host_rerror_rate  Dst_host_srv_rerror_rate  \
# 0                      0.00                   0.0                      0.00
# 1                      1.00                   0.0                      0.00
# 2                      0.01                   0.0                      0.01
# 3                      0.00                   0.0                      0.00
# 4                      0.00                   1.0                      1.00
#
#    attack_type  difficulty_level
# 0       normal                15
# 1      neptune                19
# 2       normal                21
# 3       normal                21
# 4      neptune                21
#
# [5 rows x 43 columns]
#
# ****** Start performing feature selection using ExtraTreesClassifier *****
# ****** Falls under wrapper methods (feature importance) *****
# ****** Start label encoding on the categorical features in the given dataset *****
# ****** Number of features before label encoding:  43
# ****** Number of categorical features in the dataset:  3
# ****** Categorical feature names in the dataset:  ['Protocol_type' 'Service' 'Flag']
#
# ****** Here is the list of unique values present in each categorical feature in the dataset *****
#
#
# Protocol_type: 3
# | distinct values   |
# |-------------------|
# | udp               |
# | tcp               |
# | icmp              |
#
#
# Service: 67
# | distinct values   |
# |-------------------|
# | other             |
# | private           |
# | http              |
# | remote_job        |
# | ftp_data          |
# | name              |
# | netbios_ns        |
# | eco_i             |
# | mtp               |
# | telnet            |
# | finger            |
# | domain_u          |
# | supdup            |
# | uucp_path         |
# | Z39_50            |
# | smtp              |
# | csnet_ns          |
# | uucp              |
# | netbios_dgm       |
# | urp_i             |
# | auth              |
# | domain            |
# | ftp               |
# | bgp               |
# | ldap              |
# | ecr_i             |
# | gopher            |
# | vmnet             |
# | systat            |
# | http_443          |
# | efs               |
# | whois             |
# | imap4             |
# | iso_tsap          |
# | echo              |
# | klogin            |
# | link              |
# | sunrpc            |
# | login             |
# | kshell            |
# | sql_net           |
# | time              |
# | hostnames         |
# | exec              |
# | ntp_u             |
# | discard           |
# | nntp              |
# | courier           |
# | ctf               |
# | ssh               |
# | daytime           |
# | shell             |
# | netstat           |
# | pop_3             |
# | nnsp              |
# | IRC               |
# | pop_2             |
# | printer           |
# | tim_i             |
# | pm_dump           |
# | red_i             |
# | netbios_ssn       |
# | rje               |
# | X11               |
# | urh_i             |
# | http_8001         |
# | tftp_u            |
#
#
# Flag: 11
# | distinct values   |
# |-------------------|
# | SF                |
# | S0                |
# | REJ               |
# | RSTR              |
# | SH                |
# | RSTO              |
# | S1                |
# | RSTOS0            |
# | S3                |
# | S2                |
# | OTH               |
#
# ****** Number of features after label encoding:  43
# ****** End label encoding on the categorical features in the given dataset *****
#
# ****** ExtraTreesClassification is in progress *****
#
#  selectedFeatures after ExtraTreesClassification:  Same_srv_rate                  0.079125
# difficulty_level               0.074581
# Service                        0.049435
# Dst_host_serror_rate           0.049058
# Dst_host_srv_serror_rate       0.048694
# Flag                           0.047616
# Dst_host_srv_count             0.042256
# Protocol_type                  0.041754
# Dst_host_same_srv_rate         0.040322
# Srv_serror_rate                0.040067
# Serror_rate                    0.037459
# Dst_host_same_src_port_rate    0.036510
# Logged_in                      0.035189
# Count                          0.033761
# Diff_srv_rate                  0.030027
# Dst_host_diff_srv_rate         0.029382
# Dst_host_rerror_rate           0.028935
# Src_bytes                      0.028872
# Dst_host_count                 0.026525
# dtype: float64
# ****** Completed ExtraTreesClassification *****
#
# ***** Number of columns in the dataSet after feature selection:  20
# ***** Columns in the dataSet after feature selection:
#  Index(['Protocol_type', 'Service', 'Flag', 'Src_bytes', 'Logged_in', 'Count',
#        'Serror_rate', 'Srv_serror_rate', 'Same_srv_rate', 'Diff_srv_rate',
#        'Dst_host_count', 'Dst_host_srv_count', 'Dst_host_same_srv_rate',
#        'Dst_host_diff_srv_rate', 'Dst_host_same_src_port_rate',
#        'Dst_host_serror_rate', 'Dst_host_srv_serror_rate',
#        'Dst_host_rerror_rate', 'difficulty_level', 'attack_type'],
#       dtype='object')
# ****** End performing feature selection using ExtraTreesClassifier *****
# ****** Start one hot encoding on the categorical features in the given dataset *****
# ****** Number of features before one hot encoding:  20
# ****** Number of categorical features in the dataset:  0
# ****** Categorical feature names in the dataset:  []
#
# ****** Here is the list of unique values present in each categorical feature in the dataset *****
#
#
# attack_type: 40
# | distinct values   |
# |-------------------|
# | normal            |
# | neptune           |
# | warezclient       |
# | ipsweep           |
# | portsweep         |
# | teardrop          |
# | nmap              |
# | satan             |
# | smurf             |
# | pod               |
# | back              |
# | guess_passwd      |
# | ftp_write         |
# | multihop          |
# | rootkit           |
# | buffer_overflow   |
# | imap              |
# | warezmaster       |
# | phf               |
# | land              |
# | loadmodule        |
# | spy               |
# | snmpguess         |
# | processtable      |
# | saint             |
# | mscan             |
# | apache2           |
# | httptunnel        |
# | mailbomb          |
# | snmpgetattack     |
# | worm              |
# | sendmail          |
# | xlock             |
# | xterm             |
# | xsnoop            |
# | ps                |
# | named             |
# | udpstorm          |
# | perl              |
# | sqlattack         |
#
# ****** Number of features after one hot encoding:  20
# ****** End one hot encoding on the categorical features in the given dataset *****
#
# ****** Start feature scaling of the features present in the dataset using StandardScalar *****
# [[2 41 9 ... 0.0 15 'normal']
#  [1 46 5 ... 0.0 19 'neptune']
#  [1 22 9 ... 0.0 21 'normal']
#  ...
#  [1 57 2 ... 0.85 13 'mscan']
#  [1 54 1 ... 0.88 15 'mscan']
#  [2 46 9 ... 0.0 17 'snmpguess']]
#
# ****** Number of features in the dataset before performing scaling:  19
#
# ****** Features in the dataset before performing scaling *****
#  [[2 41 9 ... 0.0 0.0 15]
#  [1 46 5 ... 1.0 0.0 19]
#  [1 22 9 ... 0.01 0.0 21]
#  ...
#  [1 57 2 ... 0.08 0.85 13]
#  [1 54 1 ... 0.0 0.88 15]
#  [2 46 9 ... 0.0 0.0 17]]
# ****** Number of features in the dataset after performing scaling:  19
#
# ****** Features in the dataset after performing scaling *****
#  [[ 2.03857058  0.6299765   0.73536923 ... -0.54981386 -0.48776502
#   -0.85380057]
#  [-0.15478617  0.93890397 -0.66099165 ...  1.89967409 -0.48776502
#    0.22813874]
#  [-0.15478617 -0.54394786  0.73536923 ... -0.52531898 -0.48776502
#    0.76910839]
#  ...
#  [-0.15478617  1.61854439 -1.70826232 ... -0.35385482  2.03171007
#   -1.39477022]
#  [-0.15478617  1.43318791 -2.05735254 ... -0.54981386  2.12063272
#   -0.85380057]
#  [ 2.03857058  0.93890397  0.73536923 ... -0.54981386 -0.48776502
#   -0.31283092]]
# scaledFeatures.head():     Protocol_type   Service      Flag  Src_bytes  Logged_in     Count  \
# 0       2.038571  0.629977  0.735369  -0.011190  -0.732914 -0.581217
# 1      -0.154786  0.938904 -0.660992  -0.011262  -0.732914  0.275339
# 2      -0.154786 -0.543948  0.735369  -0.011147   1.364417 -0.643512
# 3      -0.154786 -0.543948  0.735369  -0.011163   1.364417 -0.448840
# 4      -0.154786  0.938904 -2.057353  -0.011262  -0.732914  0.259766
#
#    Serror_rate  Srv_serror_rate  Same_srv_rate  Diff_srv_rate  Dst_host_count  \
# 0    -0.556584        -0.552030      -1.421427       0.233303        0.656445
# 1     1.851192         1.851769      -1.491319      -0.092358        0.656445
# 2    -0.075029        -0.071270       0.721924      -0.377312       -1.709884
# 3    -0.556584        -0.552030       0.721924      -0.377312        0.656445
# 4    -0.556584        -0.552030      -1.235049      -0.133066        0.656445
#
#    Dst_host_srv_count  Dst_host_same_srv_rate  Dst_host_diff_srv_rate  \
# 0           -1.050270               -1.193023                2.187298
# 1           -0.821669               -0.966271               -0.237144
# 2            1.272317                1.074493               -0.457548
# 3            1.272317                1.074493               -0.457548
# 4           -0.885678               -1.034297               -0.148983
#
#    Dst_host_same_src_port_rate  Dst_host_serror_rate  \
# 0                     2.137976             -0.561390
# 1                    -0.498320              1.904034
# 2                    -0.408446             -0.487427
# 3                    -0.498320             -0.561390
# 4                    -0.498320             -0.561390
#
#    Dst_host_srv_serror_rate  Dst_host_rerror_rate  difficulty_level  \
# 0                 -0.549814             -0.487765         -0.853801
# 1                  1.899674             -0.487765          0.228139
# 2                 -0.525319             -0.487765          0.769108
# 3                 -0.549814             -0.487765          0.769108
# 4                 -0.549814              2.476323          0.769108
#
#   attack_type
# 0      normal
# 1     neptune
# 2      normal
# 3      normal
# 4     neptune
# scaledFeatures.shape:  (37041, 20)
#
# ****** End of feature scaling of the features present in the dataset using StandardScalar *****
#
# features.shape:  (37041, 19)
# label.shape:  (37041,)
# ****** Start classification training using KNeighborsClassifier *****
#
# *** Classification accuracy score during model training:  0.9986501079913607
# testingEncodedAndScaledDataset.shape:  (14817, 20)
# *** Classification accuracy score during model testing:  0.8164945670513599
#
# ****** End classification training using KNeighborsClassifier *****

# %% [markdown]
# ### Create a excel report with the details of the models and their accuries

# %%
print(arrayOfModels)
fileName = modelPerformanceReport()
createExcelFromArray(arrayOfModels, fileName)
compareModels(arrayOfModels)
# Out:
# [['FeatureSelectionTechnique', 'FeatureEncodingTechnique', 'FeatureNormalizationTechnique', 'ClassificationTechnique', 'TrainAccuraccy', 'TestAccuraccy', 'ModelName', 'ModelFileName'], ['ExtraTreesClassifier', 'OneHotEncoder', 'Standardization', 'DecisonTree', 0.9987401007919366, 0.8164270770061416, 'ExtraTreesClassifier_OneHotEncoder_Standardization_DecisonTree', 'D:\\Learning\\DeepLearning\\Project-AttackDetectionSystem\\ModelsAndTheirPerformanceReports\\ExtraTreesClassifier_OneHotEncoder_Standardization_DecisonTree.pkl'], ['ExtraTreesClassifier', 'OneHotEncoder', 'Standardization', 'RandomForestClassifier', 0.9987401007919366, 0.8210164000809881, 'ExtraTreesClassifier_OneHotEncoder_Standardization_RandomForestClassifier', 'D:\\Learning\\DeepLearning\\Project-AttackDetectionSystem\\ModelsAndTheirPerformanceReports\\ExtraTreesClassifier_OneHotEncoder_Standardization_RandomForestClassifier.pkl'], ['ExtraTreesClassifier', 'OneHotEncoder', 'Standardization', 'ExtraTreesClassifier', 0.9987401007919366, 0.8204089896740231, 'ExtraTreesClassifier_OneHotEncoder_Standardization_ExtraTreesClassifier', 'D:\\Learning\\DeepLearning\\Project-AttackDetectionSystem\\ModelsAndTheirPerformanceReports\\ExtraTreesClassifier_OneHotEncoder_Standardization_ExtraTreesClassifier.pkl'], ['ExtraTreesClassifier', 'OneHotEncoder', 'Standardization', 'KNN', 0.9986501079913607, 0.8164945670513599, 'ExtraTreesClassifier_OneHotEncoder_Standardization_KNN', 'D:\\Learning\\DeepLearning\\Project-AttackDetectionSystem\\ModelsAndTheirPerformanceReports\\ExtraTreesClassifier_OneHotEncoder_Standardization_KNN.pkl']]
# {'RandomForestClassifier': 0.8210164000809881}
